# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\anu10\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\anu10\\Instacart Basket Analysis'

# %%
# Imported orders_products_combined
df_ords_prod = pd.read_pickle(os.path.join(path, '02 Data\Prepared Data\orders_products_combined.pkl'))

# %%
df_ords_prod.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_ords_prod.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.243449e+07  3.243449e+07  3.243449e+07  3.243449e+07
# mean   1.710749e+06  1.029372e+05  1.714205e+01  2.738818e+00
# std    9.873007e+05  5.946648e+04  1.753504e+01  2.090049e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.559430e+05  5.142100e+04  5.000000e+00  1.000000e+00
# 50%    1.711048e+06  1.026110e+05  1.100000e+01  3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243449e+07            3.035642e+07  3.243449e+07
# mean        1.342498e+01            1.110407e+01  2.557634e+04
# std         4.246365e+00            8.778914e+00  1.409669e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# 25%         1.000000e+01            5.000000e+00  1.353000e+04
# ...

# %%
df_ords_prod.shape
# Out:
# (32434489, 11)

# %% [markdown]
# # Imported dataframe and exported dataframe are same number of columns

# %%
# Imported products data set
df_order = pd.read_csv(os.path.join(path, "02 Data\Prepared Data\orders_wrangled.csv"), index_col= False)

# %%
df_order.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_products = pd.read_csv(os.path.join(path, "02 Data\Prepared Data\products_wrangled.csv"), index_col= False)

# %%
df_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# import product checked data set
df_product = pd.read_csv(os.path.join(path, "02 Data\Prepared Data\products_checked.csv"), index_col= False)

# %%
df_product.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# 5. merge the orders_products_combined and product clean data set
df_orders_products_merged = df_product.merge(df_ords_prod, on = 'product_id')

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  order_dow  \
# 0             19     5.8   3139998      138    prior            28          6
# 1             19     5.8   1977647      138    prior            30          6
# 2             19     5.8    389851      709    prior             2          0
# 3             19     5.8    652770      764    prior             1          3
# 4             19     5.8   1813452      764    prior             3          4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
# 6.Confirm the results of the merge flag
df_orders_products_merged['_merge'].value_counts()
# Out:
# both          32434212
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Checked the output
df_orders_products_merged.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17900\3490275167.py in <module>
#       1 # Checked the output
# ----> 2 df_orders_products_merged.describe()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10938         max            NaN      3.0
#   10939         """
# > 10940         return describe_ndframe(
#   10941             obj=self,
#   10942             include=include,
#
# ~\anaconda3\lib\site-packages\pandas\core\describe.py in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      99         )
#     100
# --> 101     result = describer.describe(percentiles=percentiles)
#     102     return cast(NDFrameT, result)
#     103
#
# ~\anaconda3\lib\site-packages\pandas\core\describe.py in describe(self, percentiles)
# ...

# %%
# Export data to pkl
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))

# %%
df_orders = pd.read_csv(os.path.join(path, "02 Data\Prepared Data\orders_checked.csv"), index_col= False)

# %%
df_orders.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0
